# %%
# ライブラリのインポート
import tweepy
import pandas as pd

# 取得ツイート数
count = 10000

# 検索ワード
search_word = 'ワクチン OR オミクロン OR コロナ OR 感染 OR 行動制限 OR 隔離 OR 事態宣言 OR 第7波 -filter:retweets'

#認証
CK = '0DkJ9yXBipE59f8acfsbZu1HI' # Consumer Key
CS = '77JPW1utHZVJ1Z6ghBkKcA8D4bj16DSVBz42LhduIyqMRaAUM8' # Consumer Secret
AT = '1497870821989425153-kOnrKgY5uGdFDEd2j0JnKLIclRbV5A' # Access Token
AS = 'RnXDt2d41RIsFjcw5pBD63VvHRE67GF06xuB7arcUNt6D' # Accesss Token Secert

auth = tweepy.OAuthHandler(CK, CS)
auth.set_access_token(AT, AS)

# インスタンス作成
twitter_api = tweepy.API(auth, wait_on_rate_limit=True)

# ツイート検索結果を大量取得
n = 0
data = []

for result in tweepy.Cursor(twitter_api.search_tweets, q=search_word).items(count):
   n +=1
   print('----{}-----'.format(n))
   print(result.text)
   data.append(result)


# 最新ツイートの中身を見る
data[0].text
# Out:
# ----1-----
# 日本人全体が自信を無くし、自己肯定感が無くなれば自殺するなら、優生思想、差別主義者、マウントとる連中は加害者側であり、弱者を見下す事で自信をつけている。
# 無宗教いじめ教育で国は滅びます。
#
# 為末大氏　コロナ影響で自殺者８０００人増… https://t.co/6bJkiu1Juf
# ----2-----
# @priserenity オンラインがまさかの瞬殺だったから本当に助かった😭
# ありがとう✨私の周り感染続出して今本当に多いんだと経験して知った😭
# 美月ちゃんも気をつけてね！
# ----3-----
# なにわ男子 デビュー魂 1st Love
#
# 元々同行させ頂く予定だったのですが相手の方がコロナになってしまったため、お心当たりのある方はDM頂けますと幸いです。
#
# 求 静岡 8/28
# 譲  ～11
# 枚数  1枚
# 取引方法 要相談 アプリ通し可
#
# 重複無し 初期当選 同行
# ----4-----
# @k2_ny あっこさん💕
# だいぶ元気になってきましたー！
# 家庭内感染だったので一家全滅🫠
#
# ゆっくり休んで、バンタン動画消化します💜
# ----5-----
# マスクもワクチンもどっちでも良いのにつけるな、打つなってはつけろ、打てってのと同じだと思わないのかね？
# ----6-----
# @shota_02 どうしたん🤣コロナなってノリツッコミ覚えたん🤣
# ----7-----
# スクショポイントだということを忘れてタップしてしまっていましたが、ギリギリ撮れたカワイイカレンチャン！🎀✨
# （コロナから無事復活しました！） https://t.co/BsoVUXRbnE
# ----8-----
# 「サル痘」の感染拡大が懸念されてきた～。(;´･ω･)
# 写真みたらグロすぎ！閲覧注意レベル！
# ----9-----
# コロナで出遅れたので今年初サマステ〜〜😭（最終日）
#
# たいちゃん超かわいくてかっこよかった🥲レツミュで上向くとこすき！！FocusとSlow jamめっちゃいいしCALLよすぎた🫶🏻
#
# そしてSUMMARYの本家振付を嶺亜くんが踊… https://t.co/SgE98ywk88
# ----10-----
# ...
